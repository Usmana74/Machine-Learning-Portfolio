# %% [markdown]
# <a href="https://colab.research.google.com/github/Usmana74/Machine-Learning-Portfolio/blob/main/02_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('train.csv')

# %% [markdown]
# **FOR CATEGORICAL DATA**

# %%
sns.countplot(x='Embarked',data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# **FOR PERCENTAGE**

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **FOR NUMERICAL DATA**

# %%
plt.hist(df['Age'],bins=8)
# Out:
# (array([ 64., 115., 230., 155.,  86.,  42.,  17.,   5.]),
#  array([ 0.42  , 10.3675, 20.315 , 30.2625, 40.21  , 50.1575, 60.105 ,
#         70.0525, 80.    ]),
#  <BarContainer object of 8 artists>)

# %% [markdown]
# **DETECTING OUTLIERS**

# %%
sns.boxplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# **REMOVING OUTLIERS**

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

df_no_outliers = df[(df['Age'] >= lower_limit) & (df['Age'] <= upper_limit)]

sns.boxplot(x='Age', data=df_no_outliers)
plt.title("Age Distribution After Outlier Removal")
plt.show()

# %% [markdown]
# ***KDE AND PDF***

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
