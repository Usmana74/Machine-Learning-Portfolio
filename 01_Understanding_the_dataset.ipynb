# %% [markdown]
# <a href="https://colab.research.google.com/github/Usmana74/Machine-Learning-Portfolio/blob/main/01_Understanding_the_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('train.csv')

# %% [markdown]
# **Getting a Sample**

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 35            36         0       1
# 357          358         0       2
# 809          810         1       1
# 359          360         1       3
# 395          396         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 35                   Holverson, Mr. Alexander Oskar    male  42.0      1
# 357                       Funk, Miss. Annie Clemmer  female  38.0      0
# 809  Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 359               Mockler, Miss. Helen Mary "Ellie"  female   NaN      0
# 395                             Johansson, Mr. Erik    male  22.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 35       0  113789  52.0000   NaN        S
# 357      0  237671  13.0000   NaN        S
# 809      0  113806  53.1000    E8        S
# 359      0  330980   7.8792   NaN        Q
# 395      0  350052   7.7958   NaN        S

# %% [markdown]
# **Overall dataset** **overview**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Total Rows and columns**

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# **Checking missing values**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Mathematical Computations**

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **Duplicate rows**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
